# %% [markdown]
# ### Required libraries

# %%
import tensorflow as tf

# %% [markdown]
# ### Dataset

# %%
mnist_data = tf.keras.datasets.mnist

# %% [raw]
# mnist_data.load_data()

# %%
(train_x,train_y), (test_x, test_y) = mnist_data.load_data()

# %%
epochs=10
batch_size = 32

# %% [markdown]
# ### Normalization (Converting RGB to grey scale)

# %%
train_x, test_x = tf.cast(train_x/255.0, tf.float32), tf.cast(test_x/255.0, tf.float32)
train_y, test_y = tf.cast(train_y,tf.int64),tf.cast(test_y,tf.int64)

# %% [markdown]
# ### Model01

# %%
mnistmodel1 = tf.keras.models.Sequential([
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(512,activation=tf.nn.relu),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
optimiser = tf.keras.optimizers.Adam()
mnistmodel1.compile (optimizer= optimiser, loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
mnistmodel1.fit(train_x, train_y, batch_size=128, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0042 - accuracy: 0.9985
# Epoch 2/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0046 - accuracy: 0.9984
# Epoch 3/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0042 - accuracy: 0.9984
# Epoch 4/5
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.0053 - accuracy: 0.9982
# Epoch 5/5
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0047 - accuracy: 0.9985

# %%
mnistmodel1.evaluate(test_x, test_y)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07437798599504741, 0.9841]

# %% [markdown]
# ### Model02

# %%
mnistmodel2 = tf.keras.models.Sequential();
mnistmodel2.add(tf.keras.layers.Flatten())
mnistmodel2.add(tf.keras.layers.Dense(512, activation='relu'))
mnistmodel2.add(tf.keras.layers.Dropout(0.2))
mnistmodel2.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
mnistmodel2.compile (optimizer= tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
mnistmodel2.fit(train_x, train_y, batch_size=128, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0256 - accuracy: 0.9923
# Epoch 2/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0202 - accuracy: 0.9943
# Epoch 3/5
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.0181 - accuracy: 0.9945
# Epoch 4/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.0152 - accuracy: 0.9959
# Epoch 5/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0157 - accuracy: 0.9952

# %%
mnistmodel2.evaluate(test_x, test_y)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.05946764703366789, 0.9825]

# %% [markdown]
# ### Model03

# %%
mnist = tf.keras.datasets.mnist
(train_x,train_y), (test_x, test_y) = mnist.load_data()
train_x, test_x = train_x/255.0, test_x/255.0
epochs=10

# %%
inputs = tf.keras.Input(shape=(28,28)) # Returns a 'placeholder' tensor
x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.Dense(512, activation='relu',name='d1')(x)
x = tf.keras.layers.Dropout(0.2)(x)
predictions = tf.keras.layers.Dense(10,activation=tf.nn.softmax, name='d2')(x)
mnistmodel3 = tf.keras.Model(inputs=inputs, outputs=predictions)

# %%
optimiser = tf.keras.optimizers.Adam()
mnistmodel3.compile (optimizer= optimiser, loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
mnistmodel3.fit(train_x, train_y, batch_size=128, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0147 - accuracy: 0.9953
# Epoch 2/5
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.0108 - accuracy: 0.9966
# Epoch 3/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0093 - accuracy: 0.9970
# Epoch 4/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.0092 - accuracy: 0.9971
# Epoch 5/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0070 - accuracy: 0.9976

# %%
mnistmodel3.evaluate(test_x, test_y)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.06690465550039316, 0.9839]
